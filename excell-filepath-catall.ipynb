# %%
import os
import re
import pandas as pd

# %%
file_path = r'D:\项目\梧州\派送单\demo' # 文件夹路径
file_list = os.listdir(file_path)  # 获取文件夹下所有文件的名称，包括后缀
# print(file_list)  # 结果是个list，且list中的每个元素是字符串类型

# %%
#result_df = pd.DataFrame()
def file_rd(file_path):
    path = os.path.join(file_path, file)  # 通过join得到文件的绝对路径
    read_data_1 = pd.read_excel(path, skiprows= 0) # 忽略第1行的数据，直接从第二行开始读取  
    length = len(read_data_1)
    order_id_col = path
    read_data_1['备注'] = order_id_col
    filename=file.split(".")
# 通过循环拼接每一个xlsx文件的数据
for file in file_list:
    if file.endswith(".xlsx"):  # 筛选出xlsx后缀的文件
        
        filepath = r'D:\项目\梧州\派送单\demo\res\{}.xlsx'.format(filename[0])
        read_data_1.to_excel(filepath)
    elif file.endswith(".xls"):  # 筛选出xlsx后缀的文件
        path = os.path.join(file_path, file)  # 通过join得到文件的绝对路径
        read_data_1 = pd.read_excel(path, skiprows= 0) # 忽略第1行的数据，直接从第二行开始读取  
        length = len(read_data_1)
        order_id_col = path
        read_data_1['备注'] = order_id_col
        filename=file.split(".")
        filepath = r'D:\项目\梧州\派送单\demo\res\{}.xls'.format(filename[0])
        read_data_1.to_excel(filepath)

# %%
file_path = r'D:\项目\梧州\派送单\demo\res' # 文件夹路径
file_list1 = os.listdir(file_path)  # 获取文件夹下所有文件的名称，包括后缀
# print(file_list)  # 结果是个list，且list中的每个元素是字符串类型

# %%
#合并excel
result_df = pd.DataFrame()

# 通过循环拼接每一个xlsx文件的数据
for file in file_list1:
    path = os.path.join(file_path, file)  # 通过join得到文件的绝对路径
    read_data_1 = pd.read_excel(path, skiprows= 0)
    result_df = pd.concat([result_df, read_data_1], axis = 0, sort = False)
result_df.to_excel(r'D:\项目\梧州\派送单\demo\res\合.xlsx',index = False,index_label = None )  # 将拼接的数据存储到指定文件中

# %%
read_data_1.to_excel(r'D:\项目\梧州\派送单\demo\res\filename[0].xlsx')  # 将拼接的数据存储到指定文件中
# 构造并在指定位置插入订单id列，使用insert函数（这里加在了第1列）
result_df = read_data_1.insert(10,"路径",order_id_col)  # 0 代表位置，首列
result_df
        length = len(read_data_1)
        order_id_col = path * length   
        read_data_1.insert(10, "路径", order_id_col)  # 0 代表位置，首列
        result_df.to_excel(r'D:\项目\梧州\派送单\demo\res\demo.xlsx')  # 将拼接的数据存储到指定文件中
# Out:
#   File "<ipython-input-61-f13942b69994>", line 5
#     length = len(read_data_1)
#     ^
# IndentationError: unexpected indent

# %%
#result_df = pd.DataFrame()
def file_rd(file_path):
    path = os.path.join(file_path, file)  # 通过join得到文件的绝对路径
    read_data_1 = pd.read_excel(path, skiprows= 0) # 忽略第1行的数据，直接从第二行开始读取  
    length = len(read_data_1)
    order_id_col = path
    read_data_1['备注'] = order_id_col
    filename=file.split(".")
# 通过循环拼接每一个xlsx文件的数据
for file in file_list:
    if file.endswith(".xlsx"):  # 筛选出xlsx后缀的文件
        
        filepath = r'D:\项目\梧州\派送单\demo\res\{}.xlsx'.format(filename[0])
        read_data_1.to_excel(filepath)
    elif file.endswith(".xls"):  # 筛选出xlsx后缀的文件
        path = os.path.join(file_path, file)  # 通过join得到文件的绝对路径
        read_data_1 = pd.read_excel(path, skiprows= 0) # 忽略第1行的数据，直接从第二行开始读取  
        length = len(read_data_1)
        order_id_col = path
        read_data_1['备注'] = order_id_col
        filename=file.split(".")
        filepath = r'D:\项目\梧州\派送单\demo\res\{}.xls'.format(filename[0])
        read_data_1.to_excel(filepath)

# %%
#result_df = pd.DataFrame()

# 通过循环拼接每一个xlsx文件的数据
for file in file_list:
    def file_rd(file_path_1):
        path = os.path.join(file_path_1, file)  # 通过join得到文件的绝对路径
        read_data_1 = pd.read_excel(path, skiprows= 0) # 忽略第1行的数据，直接从第二行开始读取  
        length = len(read_data_1)
        order_id_col = path
        read_data_1['备注'] = order_id_col
        filename=file.split(".")
    if file.endswith(".xlsx"):  # 筛选出xlsx后缀的文件
        file_rd(file_path)
        filepath = r'D:\项目\梧州\派送单\demo\res\{}.xlsx'.format(filename[0])
        read_data_1.to_excel(filepath)
    elif file.endswith(".xls"):  # 筛选出xlsx后缀的文件
        file_rd(file_path)
        filepath = r'D:\项目\梧州\派送单\demo\res\{}.xls'.format(filename[0])
        read_data_1.to_excel(filepath)
